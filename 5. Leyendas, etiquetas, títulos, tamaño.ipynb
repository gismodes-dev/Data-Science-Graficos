# %% [markdown]
# <a href="https://colab.research.google.com/github/guilleib227/Data-Science-Estudio/blob/main/Leyendas%2C%20etiquetas%2C%20t%C3%ADtulos%2C%20tama%C3%B1o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,5,11)
y = np.sin(x)

# %%
fig, axes = plt.subplots(1,2,figsize=(9,5))
axes[0].plot(x,y,label="$sin(x)$")
axes[0].set_title('Relacion X - Y')
axes[0].set_xlabel('X')
axes[0].set_ylabel('Y')
axes[0].legend() #para mostrar el nombre establecido en la grafica
axes[1].plot(y,x)
axes[1].set_title('Relacion Y - X')
axes[1].set_xlabel('Y')
axes[1].set_ylabel('X')
# Out:
# Text(0, 0.5, 'X')

# %%
plt.plot(x,y,label='sin(x)')
plt.title('Este es un titulo')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
